# %% [markdown]
# # Conclusion

# %% [markdown]
# #### Desired Performance: Similar or better than project 1 results (>= 99% Accuracy)

# %% [markdown]
# #### Algorithm Comparison
#
# """
# Make a table with the following columns:
# + Algorithm: sort algorithms in the order from the best to the worst.
# + Metrics (one or more columns): sort one of them from the best to the worst (probably accuracy)
# + Author: who does this algorithm.
# """

# %% [markdown]
# #### Do your algorithms achieve the desired performance? If not, what reasons? What dis we learn from doing the projects?
#
# """
# ANSWER
# """
