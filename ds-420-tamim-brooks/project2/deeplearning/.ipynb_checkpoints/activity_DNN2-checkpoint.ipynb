# %% [markdown]
# # Activity Classification - DNN2 Training
#
# This notebook trains our second Deep Neural Network on the physical activity dataset.

# %% [markdown]
# ## Load Data and Prepare Training Set

# %%
# %reset -f

import importlib
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import activity_functions
importlib.reload(activity_functions)

from activity_functions import *

# %%
activtity = load_data()
# Out:
# Loaded from Kaggle: /home/thuy/.cache/kagglehub/datasets/diegosilvadefrana/fisical-activity-dataset/versions/4/dataset2.csv

# %%
df_train, df_test = create_train_test(activtity, test_ratio=0.2)
print(df_train.shape)
print(df_test.shape)
# Out:
# (2291244, 33)
# (572812, 33)

# %%
X_train, y_train, X_test, y_test = prepare_for_train(df_train, df_test)

# %% [markdown]
# ## HYPERTUNE SOMEWHERE

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
y_train_encoded = encoder.fit_transform(y_train)

# %%
#hyperband

# %%
tuner = kt.Hyperband(
    build_model_cnn,
    objective="val_accuracy",
    max_epochs=100,
    factor=3,
    directory="my_dir2",
    project_name="hyperband_tuning"
)

batch_sizes = [32, 64, 128]
for batch in batch_sizes:
    tuner.search(X_train, y_train_encoded, epochs=100, validation_split=0.2, batch_size=batch)

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# Search: Running Trial #1
#
# Value             |Best Value So Far |Hyperparameter
# 2                 |2                 |n_hidden
# 3                 |3                 |n_conv_layers
# 0.00011454        |0.00011454        |learning_rate
# sgd               |sgd               |optimizer
# 32                |32                |filters_0
# 5                 |5                 |kernel_size_0
# selu              |selu              |conv_activation
# 128               |128               |filters_1
# 3                 |3                 |kernel_size_1
# 256               |256               |dense_units_0
# tanh              |tanh              |dense_activation_0
# 0.2               |0.2               |dropout_0
# 128               |128               |dense_units_1
# tanh              |tanh              |dense_activation_1
# 0.5               |0.5               |dropout_1
# 2                 |2                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 4                 |4                 |tuner/bracket
# 0                 |0                 |tuner/round
#
# Epoch 1/2
# 57282/57282 ━━━━━━━━━━━━━━━━━━━━ 365s 6ms/step - accuracy: 0.4572 - loss: 1.7359 - val_accuracy: 0.6214 - val_loss: 1.2296
# Epoch 2/2
# 57282/57282 ━━━━━━━━━━━━━━━━━━━━ 388s 7ms/step - accuracy: 0.6423 - loss: 1.1436 - val_accuracy: 0.7322 - val_loss: 0.8818
# ---------------------------------------------------------------------------
# FatalTypeError                            Traceback (most recent call last)
# Cell In[34], line 17
#       2 import keras_tuner as kt
#       3 tuner = kt.Hyperband(
#       4     build_model_cnn,
#       5     objective=None,
#    (...)
#      14     max_consecutive_failed_trials=3
#      15 )
# ---> 17 tuner.search(X_train, y_train_encoded, epochs=10, validation_split=0.2)
#      18 best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
#
# File ~/miniconda3/envs/ds420/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File ~/miniconda3/envs/ds420/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py:279, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     277 except Exception as e:
#     278     if isinstance(e, errors.FatalError):
# --> 279         raise e
#     280     if config_module.DEBUG:
#     281         # Printing the stacktrace and the error.
#     282         traceback.print_exc()
#
# File ~/miniconda3/envs/ds420/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File ~/miniconda3/envs/ds420/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File ~/miniconda3/envs/ds420/lib/python3.10/site-packages/keras_tuner/src/tuners/hyperband.py:427, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     425     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427 return super().run_trial(trial, *fit_args, **fit_kwargs)
#
# File ~/miniconda3/envs/ds420/lib/python3.10/site-packages/keras_tuner/src/engine/tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File ~/miniconda3/envs/ds420/lib/python3.10/site-packages/keras_tuner/src/engine/tuner.py:242, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     236 if backend.config.multi_backend():
#     237     utils.save_json(
#     238         self._get_build_config_fname(trial.trial_id),
#     239         model.get_build_config(),
#     240     )
# --> 242 tuner_utils.validate_trial_results(
#     243     results, self.oracle.objective, "HyperModel.fit()"
#     244 )
#     245 return results
#
# File ~/miniconda3/envs/ds420/lib/python3.10/site-packages/keras_tuner/src/engine/tuner_utils.py:173, in validate_trial_results(results, objective, func_name)
#     168 # objective left unspecified,
#     169 # and objective value is not a single float.
#     170 if isinstance(objective, obj_module.DefaultObjective) and not (
#     171     isinstance(results, dict) and objective.name in results
#     172 ):
# --> 173     raise errors.FatalTypeError(
#     174         f"Expected the return value of {func_name} to be "
#     175         "a single float when `objective` is left unspecified. "
#     176         f"Recevied return value: {results} of type {type(results)}."
#     177     )
#     179 # A dictionary.
#     180 if isinstance(results, dict):
#
# FatalTypeError: Expected the return value of HyperModel.fit() to be a single float when `objective` is left unspecified. Recevied return value: <keras.src.callbacks.history.History object at 0x7f78d2104940> of type <class 'keras.src.callbacks.history.History'>.

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best hyperparameters:")
print(f"  learning_rate: {best_hps.get('learning_rate')}")
print(f"  optimizer: {best_hps.get('optimizer')}")
print(f"  dropout: {best_hps.get('dropout')}")

# %% [markdown]
# ## Model Fit

# %%
best_model = tuner.hypermodel.build(best_hps)
callback = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=5, restore_best_weights=True)
history = best_model.fit(X_train, y_train_encoded, epochs=50, validation_split=0.2, callbacks=[callback])

# %% [markdown]
# ## Model Evaluation

# %%
y_test_hat = best_model.predict(X_test)
y_test_pred = np.argmax(y_test_hat, axis=1)
compute_scores(y_test, y_test_pred, verbose=True)

# %% [markdown]
# ## Summary
#
# Discuss results
